# %%
# !pip install gender_guesser
# Out:
# Collecting gender_guesser
#   Downloading gender_guesser-0.4.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Downloading gender_guesser-0.4.0-py2.py3-none-any.whl (379 kB)
# Installing collected packages: gender_guesser
# Successfully installed gender_guesser-0.4.0

# %%
import pandas as pd

# %%
novostroy_df = pd.read_csv("reviews.csv")
zkh_df = pd.read_csv("forum-zhk.csv")

# %%
novostroy_df
# Out:
#                       Name        Date  \
# 0                    Алина  2025-01-31
# 1                   Михаил  2025-01-28
# 2           Ольга Николина  2025-01-24
# 3       Евгения Жовниренко  2025-01-21
# 4                   Мarina  2025-01-20
# ..                     ...         ...
# 390        Евгений Filipov  2018-07-09
# 391           Пользователь  2018-07-05
# 392           Пользователь  2018-05-08
# 393  Полина Полина Гришина  2018-05-07
# 394                  Слава  2018-02-27
#
#                                                 Review  Rating
# 0    К выбору квартиры подошла основательно. Сначал...       5
# 1    Переехали мы год назад в новостройку от компан...       1
# 2    Живу пол года в жилом комплексе Пригород Лесно...       5
# 3    Категорически не рекомендую самолёт.Все отличн...       1
# 4    Остановилась на несколько ЖК от Самолёта, но в...       5
# ..                                                 ...     ...
# 390  Все нормально , но если какая то проблема в от...       1
# 391       Проблему по ЖК ОСТАФЬЕВО, решили оперативно!       5
# 392  Здравствуйте! Купили квартиру в Люберцах. Срок...       3
# 393  Задумалась о покупке квартиры в ЖК спутник . В...       3
# 394  Хорошая компания, надежная. Сроки задерживают?...       5
#
# [395 rows x 4 columns]

# %%
zkh_df = zkh_df.dropna()
zkh_df = zkh_df[~zkh_df["Review"].str.startswith("Siteinfo: IP-адреса отзывов из одной", na=False)]
zkh_df["Date"] = pd.to_datetime(zkh_df["Date"], format="%d.%m.%Y %H:%M").dt.strftime("%Y-%m-%d")
zkh_df["Rating"] = zkh_df["Rating"].apply(int)
combined_df = pd.concat([novostroy_df, zkh_df], ignore_index=True)

# %%
combined_df.to_csv("United_data.csv")

# %% [markdown]
# ### Длинна комментария

# %%
combined_df["Review_Length"] = combined_df["Review"].str.len()

# %% [markdown]
# ### Добавить столбец с полом пользователя

# %%
# !pip install natasha
# !pip install setuptools

# %%
from natasha import (
    NamesExtractor,
    MorphVocab
)

# %%
# Создаём морфологический словарь
morph_vocab = MorphVocab()

# Передаём его в конструктор NamesExtractor
names_extractor = NamesExtractor(morph_vocab)

def get_first_name(full_name: str) -> str:
    clean_name = full_name.replace('.', ' ').replace(',', ' ').strip()
    
    # Преобразуем результат NamesExtractor в список
    matches = list(names_extractor(clean_name))
    
    if not matches:
        # Фоллбэк: берем первое слово
        return clean_name.split()[0]
    
    parsed_name = matches[0].fact.first
    if parsed_name is None:
        parsed_name = clean_name.split()[0]
    
    return parsed_name

def determine_gender(name: str) -> str:
    """
    Определяем пол на основе имени, используя простые правила и данные Natasha.
    Возможные возвращаемые значения: "male", "female", "unknown".
    """
    # Пытаемся разобрать как PersonName
    # Сам Natasha для пола напрямую полную проверку не даёт, 
    # но можно по косвенным признакам определять,
    # либо использовать pymorphy2 (см. ниже).
    
    # Для примера покажем простой набор эвристик:
    # - Если имя заканчивается на "а", "я", "ия" и т.п. -> female (с оговорками)
    # - Иначе предполагаем male.
    # Вы можете усложнить этот блок любым нужным вам способом, 
    # подключить дополнительную словарную базу, сделать исключения и т.д.
    
    # Переведём в нижний регистр для удобства проверок
    name_lower = name.lower()
    
    # Несколько самых частых женских окончаний
    female_endings = ("а", "я", "ия", "иа", "на", "ся", "ля")
    
    # Допустим, если слово оканчивается на любое из этих окончаний, считаем женским именем
    if any(name_lower.endswith(end) for end in female_endings):
        return "female"
    
    # Иначе — мужское (с учётом, что бывают «Саша», «Женя» и т. д., где неоднозначность,
    # для такой неоднозначности можно добавить отдельный список исключений)
    # Но для упрощённого варианта говорим, что всё остальное — мужское.
    return "male"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 2
#       1 # Создаём морфологический словарь
# ----> 2 morph_vocab = MorphVocab()
#       4 # Передаём его в конструктор NamesExtractor
#       5 names_extractor = NamesExtractor(morph_vocab)
#
# File ~/Documents/add_hse/santiment_detection/venv/lib/python3.13/site-packages/natasha/morph/vocab.py:162, in MorphVocab.__init__(self)
#     161 def __init__(self):
# --> 162     PymorphyAnalyzer.__init__(self, result_type=MorphForm)
#
# File ~/Documents/add_hse/santiment_detection/venv/lib/python3.13/site-packages/pymorphy2/analyzer.py:200, in MorphAnalyzer.__init__(self, path, lang, result_type, units, probability_estimator_cls, char_substitutes)
#     197 if path is None and lang is None:
#     198     lang = 'ru'
# --> 200 path = self.choose_dictionary_path(path, lang)
#     202 with self._lock:
#     203     self.dictionary = opencorpora_dict.Dictionary(path)
#
# File ~/Documents/add_hse/santiment_detection/venv/lib/python3.13/site-packages/pymorphy2/analyzer.py:280, in MorphAnalyzer.choose_dictionary_path(cls, path, lang)
#     277 if cls.DICT_PATH_ENV_VARIABLE in os.environ:
#     278     return os.environ[cls.DICT_PATH_ENV_VARIABLE]
# --> 280 return lang_dict_path(lang)
#
# File ~/Documents/add_hse/santiment_detection/venv/lib/python3.13/site-packages/pymorphy2/analyzer.py:141, in lang_dict_path(lang)
#     138 if lang in lang_paths:
#     139     return lang_paths[lang]
# --> 141 raise ValueError(
#     142     "Can't find a dictionary for language %r. Installed languages: %r. "
#     143     "Try installing pymorphy2-dicts-%s package." % (
#     144         lang, list(lang_paths.keys()), lang
#     145     )
#     146 )
#
# ValueError: Can't find a dictionary for language 'ru'. Installed languages: []. Try installing pymorphy2-dicts-ru package.

# %%
combined_df["FirstName"] = combined_df["Name"].apply(get_first_name)

# %%
combined_df
# Out:
#                    Name        Date  \
# 0                 Алина  2025-01-31
# 1                Михаил  2025-01-28
# 2        Ольга Николина  2025-01-24
# 3    Евгения Жовниренко  2025-01-21
# 4                Мarina  2025-01-20
# ..                  ...         ...
# 411               Нонна  2018-03-29
# 412            Надежда.  2018-01-19
# 413             Татьяна  2017-08-20
# 414              Ксения  2017-01-27
# 415     Руслан Рахматов  2014-12-05
#
#                                                 Review  Rating  Review_Length  \
# 0    К выбору квартиры подошла основательно. Сначал...       5            238
# 1    Переехали мы год назад в новостройку от компан...       1            752
# 2    Живу пол года в жилом комплексе Пригород Лесно...       5            223
# 3    Категорически не рекомендую самолёт.Все отличн...       1            561
# 4    Остановилась на несколько ЖК от Самолёта, но в...       5            664
# ..                                                 ...     ...            ...
# 411  Хочу связаться с Группой Самолет.Но есть опасе...       4            232
# 412  Купили квартиру в новостройке ЖК Томилино 2018...       4            215
# 413                 Есть вакансия кладовщика свободная       3             34
# 414  Отличный застройщик!все во время сдал,квартиру...       5            228
# 415  строители каменщики,бригада с ТУЛЬСКОЙ области...       4            110
#
#     FirstName
# 0       Алина
# 1      Михаил
# 2       Ольга
# 3     Евгения
# 4      Мarina
# ..        ...
# 411     Нонна
# 412   Надежда
# 413   Татьяна
# 414    Ксения
# 415    Руслан
#
# [416 rows x 6 columns]

# %%
combined_df["Gender"] = combined_df["FirstName"].apply(determine_gender)

# %%
combined_df
# Out:
#                    Name        Date  \
# 0                 Алина  2025-01-31
# 1                Михаил  2025-01-28
# 2        Ольга Николина  2025-01-24
# 3    Евгения Жовниренко  2025-01-21
# 4                Мarina  2025-01-20
# ..                  ...         ...
# 411               Нонна  2018-03-29
# 412            Надежда.  2018-01-19
# 413             Татьяна  2017-08-20
# 414              Ксения  2017-01-27
# 415     Руслан Рахматов  2014-12-05
#
#                                                 Review  Rating  Review_Length  \
# 0    К выбору квартиры подошла основательно. Сначал...       5            238
# 1    Переехали мы год назад в новостройку от компан...       1            752
# 2    Живу пол года в жилом комплексе Пригород Лесно...       5            223
# 3    Категорически не рекомендую самолёт.Все отличн...       1            561
# 4    Остановилась на несколько ЖК от Самолёта, но в...       5            664
# ..                                                 ...     ...            ...
# 411  Хочу связаться с Группой Самолет.Но есть опасе...       4            232
# 412  Купили квартиру в новостройке ЖК Томилино 2018...       4            215
# 413                 Есть вакансия кладовщика свободная       3             34
# 414  Отличный застройщик!все во время сдал,квартиру...       5            228
# 415  строители каменщики,бригада с ТУЛЬСКОЙ области...       4            110
#
#     FirstName  Gender
# 0       Алина  female
# 1      Михаил    male
# 2       Ольга  female
# 3     Евгения  female
# 4      Мarina    male
# ..        ...     ...
# 411     Нонна  female
# 412   Надежда  female
# 413   Татьяна  female
# 414    Ксения  female
# 415    Руслан    male
#
# [416 rows x 7 columns]

# %%
combined_df["Gender"].value_counts()
# Out:
# Gender
# male      214
# female    202
# Name: count, dtype: int64

# %%
combined_df
# Out:
#                    Name        Date  \
# 0                 Алина  2025-01-31
# 1                Михаил  2025-01-28
# 2        Ольга Николина  2025-01-24
# 3    Евгения Жовниренко  2025-01-21
# 4                Мarina  2025-01-20
# ..                  ...         ...
# 411               Нонна  2018-03-29
# 412            Надежда.  2018-01-19
# 413             Татьяна  2017-08-20
# 414              Ксения  2017-01-27
# 415     Руслан Рахматов  2014-12-05
#
#                                                 Review  Rating  Review_Length  \
# 0    К выбору квартиры подошла основательно. Сначал...       5            238
# 1    Переехали мы год назад в новостройку от компан...       1            752
# 2    Живу пол года в жилом комплексе Пригород Лесно...       5            223
# 3    Категорически не рекомендую самолёт.Все отличн...       1            561
# 4    Остановилась на несколько ЖК от Самолёта, но в...       5            664
# ..                                                 ...     ...            ...
# 411  Хочу связаться с Группой Самолет.Но есть опасе...       4            232
# 412  Купили квартиру в новостройке ЖК Томилино 2018...       4            215
# 413                 Есть вакансия кладовщика свободная       3             34
# 414  Отличный застройщик!все во время сдал,квартиру...       5            228
# 415  строители каменщики,бригада с ТУЛЬСКОЙ области...       4            110
#
#     FirstName  Gender
# 0       Алина  female
# 1      Михаил    male
# 2       Ольга  female
# 3     Евгения  female
# 4      Мarina    male
# ..        ...     ...
# 411     Нонна  female
# 412   Надежда  female
# 413   Татьяна  female
# 414    Ксения  female
# 415    Руслан    male
#
# [416 rows x 7 columns]

# %%
combined_df.to_csv("United_data.csv")

# %% [markdown]
# ### Добавление данных

# %%
combined_df_cutted = combined_df[
    [
        "Name",
        "Date",
        "Review"
    ]
]

# %%
sec_data = pd.read_csv("novostroev_reviews.csv")

# %%
sec_data["Date"] = pd.to_datetime(sec_data["Date"], format="%d.%m.%Y %H:%M").dt.strftime("%Y-%m-%d")

# %%
sec_data
# Out:
#                Name        Date  \
# 0    Яна Купчиненко  2024-05-02
# 1             Елена  2021-11-23
# 2              петр  2019-11-15
# 3            Митрий  2020-09-09
# 4            Сергей  2020-11-26
# ..              ...         ...
# 759         Николай  2024-06-05
# 760             Али  2024-02-27
# 761            Юлия  2024-02-06
# 762       Екатерина  2024-03-05
# 763            Анна  2024-05-20
#
#                                                 Review
# 0    Мы проживаем в жк Алхимово, ни разу не пожалел...
# 1    У нас знакомые квартиру взяли у этого застройщ...
# 2    все хвалебные отзывы - вранье...контора гнилая...
# 3    Так это же стандарт такой : "Прагматик" называ...
# 4                                   Не выдумывай бро))
# ..                                                 ...
# 759  Приветствую всех желающих купить квартиру у ГК...
# 760  Отвратительная компания, хуже во всем ( стройк...
# 761  Отвратительное и неприятное общение в офисе пр...
# 762  При приеме квартиры были недочеты. Исправлять ...
# 763  Уважаемый "Самолет"!!! Обратите внимание на ЖК...
#
# [764 rows x 3 columns]

# %%
combined_df_cutted
# Out:
#                    Name        Date  \
# 0                 Алина  2025-01-31
# 1                Михаил  2025-01-28
# 2        Ольга Николина  2025-01-24
# 3    Евгения Жовниренко  2025-01-21
# 4                Мarina  2025-01-20
# ..                  ...         ...
# 411               Нонна  2018-03-29
# 412            Надежда.  2018-01-19
# 413             Татьяна  2017-08-20
# 414              Ксения  2017-01-27
# 415     Руслан Рахматов  2014-12-05
#
#                                                 Review
# 0    К выбору квартиры подошла основательно. Сначал...
# 1    Переехали мы год назад в новостройку от компан...
# 2    Живу пол года в жилом комплексе Пригород Лесно...
# 3    Категорически не рекомендую самолёт.Все отличн...
# 4    Остановилась на несколько ЖК от Самолёта, но в...
# ..                                                 ...
# 411  Хочу связаться с Группой Самолет.Но есть опасе...
# 412  Купили квартиру в новостройке ЖК Томилино 2018...
# 413                 Есть вакансия кладовщика свободная
# 414  Отличный застройщик!все во время сдал,квартиру...
# 415  строители каменщики,бригада с ТУЛЬСКОЙ области...
#
# [416 rows x 3 columns]

# %%
massive_data = pd.concat([combined_df_cutted, sec_data], ignore_index=True)

# %%
massive_data
# Out:
#                     Name        Date  \
# 0                  Алина  2025-01-31
# 1                 Михаил  2025-01-28
# 2         Ольга Николина  2025-01-24
# 3     Евгения Жовниренко  2025-01-21
# 4                 Мarina  2025-01-20
# ...                  ...         ...
# 1175             Николай  2024-06-05
# 1176                 Али  2024-02-27
# 1177                Юлия  2024-02-06
# 1178           Екатерина  2024-03-05
# 1179                Анна  2024-05-20
#
#                                                  Review
# 0     К выбору квартиры подошла основательно. Сначал...
# 1     Переехали мы год назад в новостройку от компан...
# 2     Живу пол года в жилом комплексе Пригород Лесно...
# 3     Категорически не рекомендую самолёт.Все отличн...
# 4     Остановилась на несколько ЖК от Самолёта, но в...
# ...                                                 ...
# 1175  Приветствую всех желающих купить квартиру у ГК...
# 1176  Отвратительная компания, хуже во всем ( стройк...
# 1177  Отвратительное и неприятное общение в офисе пр...
# 1178  При приеме квартиры были недочеты. Исправлять ...
# 1179  Уважаемый "Самолет"!!! Обратите внимание на ЖК...
#
# [1180 rows x 3 columns]

# %%
massive_data.to_csv("collected_data.csv")

# %% [markdown]
# # SDF

# %%
import pandas as pd

# %%
df = pd.read_csv("merged_4_sites.csv", index_col=0)

# %%
df
# Out:
#                       Name        Date  \
# 0                   Никита  2025-02-28
# 1                   Галина  2025-02-26
# 2                  Наталья  2025-02-19
# 3     Валентина Гвоздилова  2025-02-14
# 4           Дмитрий Усачин  2025-02-08
# ...                    ...         ...
# 1846           Елена197967  2018-06-25
# 1847       Алексей Ильичёв  2019-02-18
# 1848          Елена7779898  2018-04-11
# 1849            polinavoda  2019-11-06
# 1850      mamadjonova54321  2021-01-16
#
#                                                  Review  Rating Developer  \
# 0     Мы живем в арендованной квартире 8 лет. Вернее...     5.0   samolet
# 1     При покупке студии в Молжаниново была завышена...     1.0   samolet
# 2     Удачно переехали в Горки парк, сейчас вот ждем...     5.0   samolet
# 3     Живем с мужем и сыном в ЖК Большое Путилково у...     5.0   samolet
# 4     Мне комфортно в Новом Внукове от Самолёта. Дом...     5.0   samolet
# ...                                                 ...     ...       ...
# 1846  Купили квартиру и очень пожалели. 1. Гранель н...     1.0    granel
# 1847  Ночь 3.51 жена говорит у нас крыша взлетает) К...     1.0    granel
# 1848  Решила купить квартиру и сразу начались пробле...     1.0    granel
# 1849  Брали квартиру без отделки, поэтому, конечно, ...     5.0    granel
# 1850  С отделкой не стоит покупать. Очень много жало...     1.0    granel
#
#            Site
# 0     novostroy
# 1     novostroy
# 2     novostroy
# 3     novostroy
# 4     novostroy
# ...         ...
# 1846    otzovik
# 1847    otzovik
# 1848    otzovik
# 1849    otzovik
# 1850    otzovik
#
# [1851 rows x 6 columns]

# %%
df["Review"] = df["Review"].str.replace("Достоинства:", "", regex=False)
df["Review"] = df["Review"].str.replace("Недостатки:", "", regex=False)

# %%
df.to_csv("merged_4_sites.csv")

# %%
df
# Out:
#                       Name        Date  \
# 0                   Никита  2025-02-28
# 1                   Галина  2025-02-26
# 2                  Наталья  2025-02-19
# 3     Валентина Гвоздилова  2025-02-14
# 4           Дмитрий Усачин  2025-02-08
# ...                    ...         ...
# 1846           Елена197967  2018-06-25
# 1847       Алексей Ильичёв  2019-02-18
# 1848          Елена7779898  2018-04-11
# 1849            polinavoda  2019-11-06
# 1850      mamadjonova54321  2021-01-16
#
#                                                  Review  Rating Developer  \
# 0     Мы живем в арендованной квартире 8 лет. Вернее...     5.0   samolet
# 1     При покупке студии в Молжаниново была завышена...     1.0   samolet
# 2     Удачно переехали в Горки парк, сейчас вот ждем...     5.0   samolet
# 3     Живем с мужем и сыном в ЖК Большое Путилково у...     5.0   samolet
# 4     Мне комфортно в Новом Внукове от Самолёта. Дом...     5.0   samolet
# ...                                                 ...     ...       ...
# 1846  Купили квартиру и очень пожалели. 1. Гранель н...     1.0    granel
# 1847  Ночь 3.51 жена говорит у нас крыша взлетает) К...     1.0    granel
# 1848  Решила купить квартиру и сразу начались пробле...     1.0    granel
# 1849  Брали квартиру без отделки, поэтому, конечно, ...     5.0    granel
# 1850  С отделкой не стоит покупать. Очень много жало...     1.0    granel
#
#            Site
# 0     novostroy
# 1     novostroy
# 2     novostroy
# 3     novostroy
# 4     novostroy
# ...         ...
# 1846    otzovik
# 1847    otzovik
# 1848    otzovik
# 1849    otzovik
# 1850    otzovik
#
# [1851 rows x 6 columns]

# %%
df = pd.read_csv("Сантимент - merged_4_sites.csv", index_col=0)

# %%
df.to_csv("collected_data.csv")

# %%
df
# Out:
#                       Name        Date  \
# 0                   Никита  2025-02-28
# 1                   Галина  2025-02-26
# 2                  Наталья  2025-02-19
# 3     Валентина Гвоздилова  2025-02-14
# 4           Дмитрий Усачин  2025-02-08
# ...                    ...         ...
# 1846           Елена197967  2018-06-25
# 1847       Алексей Ильичёв  2019-02-18
# 1848          Елена7779898  2018-04-11
# 1849            polinavoda  2019-11-06
# 1850      mamadjonova54321  2021-01-16
#
#                                                  Review  Rating Developer  \
# 0     Мы живем в арендованной квартире 8 лет. Вернее...     5.0   samolet
# 1     При покупке студии в Молжаниново была завышена...     1.0   samolet
# 2     Удачно переехали в Горки парк, сейчас вот ждем...     5.0   samolet
# 3     Живем с мужем и сыном в ЖК Большое Путилково у...     5.0   samolet
# 4     Мне комфортно в Новом Внукове от Самолёта. Дом...     5.0   samolet
# ...                                                 ...     ...       ...
# 1846  Купили квартиру и очень пожалели. 1. Гранель н...     1.0    granel
# 1847  Ночь 3.51 жена говорит у нас крыша взлетает) К...     1.0    granel
# 1848  Решила купить квартиру и сразу начались пробле...     1.0    granel
# 1849  Брали квартиру без отделки, поэтому, конечно, ...     5.0    granel
# 1850  С отделкой не стоит покупать. Очень много жало...     1.0    granel
#
#            Site  True_santiment
# 0     novostroy               1
# 1     novostroy              -1
# 2     novostroy               1
# 3     novostroy               1
# 4     novostroy               1
# ...         ...             ...
# 1846    otzovik              -1
# 1847    otzovik               0
# 1848    otzovik              -1
# 1849    otzovik               1
# 1850    otzovik              -1
#
# [1851 rows x 7 columns]
